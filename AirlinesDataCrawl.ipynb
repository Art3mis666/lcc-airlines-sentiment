# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
def video_comments(video_id):
  replies=[]
  youtube=build('youtube','v3',developerKey=api_key)
  video_response=youtube.commentThreads().list(part='snippet,replies',videoId=video_id).execute()

  while video_response:
    for item in video_response['items']:
      published=item['snippet']['topLevelComment']['snippet']['publishedAt']
      user=item['snippet']['topLevelComment']['snippet']['authorDisplayName']
      comment=item['snippet']['topLevelComment']['snippet']['textDisplay']
      likeCount=item['snippet']['topLevelComment']['snippet']['likeCount']

      replies.append([published,user,comment,likeCount])

      replyCount=item['snippet']['totalReplyCount']

      if replyCount>0:
        for reply in item['replies']['comments']:
          published=reply['snippet']['publishedAt']
          user=reply['snippet']['authorDisplayName']
          repl=reply['snippet']['textDisplay']
          likeCount=reply['snippet']['likeCount']
      
    if 'nextPageToken' in video_response:
      video_response=youtube.commentThreads().list(
        part='snippet,replies',
        pageToken=video_response['nextPageToken'],
        videoId=video_id
      ).execute()
    else:
      break
  return replies

# %%
api_key='AIzaSyCwFHbDZxKxisk068qsjbE-53a_McJVLI0'
video_id='ZTa6TCJWvkc'

comments=video_comments(video_id)
comments
# Out:
# [['2019-11-15T00:27:28Z',
#   'ikhwanhidayat',
#   'Beli tiket pesawat di Tiket com: <a href="https://invol.co/clj4sv">https://invol.co/clj4sv</a><br><br>Kamera DJI OSMO POCKET<br>Lazada (Sekarang Rp. 4 jutaan): <a href="https://invol.co/clj4ss">https://invol.co/clj4ss</a>',
#   28],
#  ['2023-01-17T08:29:37Z',
#   'Komang Dika',
#   'Mas Ikhwan, mas coba naik pesawat malang-denpasar dong😅',
#   1],
#  ['2022-11-07T08:22:59Z',
#   'Fabio Matasak',
#   'Di video kali ini Ikhwan Hidayat akan terbang dari Bandara Internasional Palangkaraya Kalimantan menuju ke Bandara internasional Soekarno-Hatta Jakarta dengan pesawat Lion Air Boeing 737 - 800',
#   1],
#  ['2022-05-27T12:05:28Z',
#   'Nurazizah Anwariani',
#   'Hallo kaa, kalo boleh tau lion air dri pky waktu nyampe jkt bndra seota itu terminal brpa ya ka?',
#   1],
#  ['2022-05-18T08:02:47Z',
#   'Richard Vidi Wibisana',
#   'Naik Citilink ke pekan baru',
#   1],
#  ['2022-04-07T01:20:21Z',
#   'Cessillia Lia',
# ...

# %%
df=pd.DataFrame(comments,columns=['publishedAt','authorDisplayName','textDisplay','likeCount'])
df
# Out:
#               publishedAt      authorDisplayName  \
# 0    2019-11-15T00:27:28Z          ikhwanhidayat
# 1    2023-01-17T08:29:37Z            Komang Dika
# 2    2022-11-07T08:22:59Z          Fabio Matasak
# 3    2022-05-27T12:05:28Z    Nurazizah Anwariani
# 4    2022-05-18T08:02:47Z  Richard Vidi Wibisana
# ..                    ...                    ...
# 409  2019-09-14T09:31:20Z         Siska Fitriani
# 410  2019-09-14T09:31:16Z                   Dy Y
# 411  2019-09-14T09:31:03Z                   Dy Y
# 412  2019-09-14T09:31:01Z               Just4Fun
# 413  2019-09-14T09:30:59Z                  Cruz.
#
#                                            textDisplay  likeCount
# 0    Beli tiket pesawat di Tiket com: <a href="http...         28
# 1    Mas Ikhwan, mas coba naik pesawat malang-denpa...          1
# 2    Di video kali ini Ikhwan Hidayat akan terbang ...          1
# 3    Hallo kaa, kalo boleh tau lion air dri pky wak...          1
# ...

# %%
df.to_excel('ytcomments_ikhwanhidayat_lionair.xlsx')
